# %%
import duckdb
with duckdb.connect("../ads_data.duckdb") as connection:
    df_mart = connection.execute("SELECT * FROM mart.mart_ads").df()
df_mart.head()
# Out:
#                                         headline               occupation  \
# 0                              Industrieketriker       Industrielektriker
# 1  Lagertekniker (Deltid/Extra) – Crona Software    Servicetekniker, data
# 2                                   Bilmekaniker      Personbilsmekaniker
# 3                              Verkstadstekniker  Servicetekniker, maskin
# 4                      Tågmontör med elkompetens     Servicetekniker, tåg
#
#                                     occupation_group  \
# 0                                 Industrielektriker
# 1  Elektronikreparatörer och kommunikationselektr...
# 2       Motorfordonsmekaniker och fordonsreparatörer
# 3       Motorfordonsmekaniker och fordonsreparatörer
# 4          Underhållsmekaniker och maskinreparatörer
#
#                  occupation_field  \
# 0  Installation, drift, underhåll
# 1  Installation, drift, underhåll
# 2  Installation, drift, underhåll
# 3  Installation, drift, underhåll
# 4  Installation, drift, underhåll
#
#                                          description                duration  \
# 0  Tedelektro håller på att expandera och vi behö...            Tills vidare
# 1  Lagertekniker (Deltid/Extra) – Crona Software\...              ej angiven
# 2  Vi söker en bilmekaniker som vill jobba anting...            Tills vidare
# 3  Är du vår nya verkstadstekniker? Vi expander o...            Tills vidare
# 4  Plats: Falköping\nStartdatum: 2025-05-15 \nAns...  6 månader eller längre
#
#   working_hours_type  scope_of_work_min  scope_of_work_max  vacancies  \
# 0             Heltid                100                100          1
# 1               None               <NA>               <NA>          1
# 2             Heltid                100                100          1
# 3             Heltid                100                100          2
# 4             Heltid                100                100          1
#
#                              employer_name      workplace_region  \
# 0                            Tedelektro AB            ej angiven
# 1                        Crona Software AB             Skåne län
# 2  Landvetter Bilverkstad Br. Josefsson AB  Västra götalands län
# 3                      Liebherr-Sverige AB      Västmanlands län
# 4                      Railforce Sweden AB  Västra götalands län
#
#   workplace_city  experience_required  driving_license  access_to_own_car  \
# 0     ej angiven                 True             True              False
# 1    Helsingborg                 True             True              False
# 2        Härryda                 True             True              False
# 3       Västerås                 True             True              False
# 4      Falköping                 True             True              False
#
#   must_have_languages
# 0             Svenska
# 1             Svenska
# 2             Svenska
# 3   Engelska, Svenska
# 4   Engelska, Svenska

# %%
df_mart["workplace_city"]("vacancies")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df_mart["workplace_city"]("vacancies")
#
# TypeError: 'Series' object is not callable

# %%
import plotly.express as px

# px.bar(df.head(10), x="workplace_city", y="vacancies")
df = df_mart.groupby("workplace_city")["vacancies"].sum().sort_values(ascending=False).reset_index().head(10)
df
# Out:
#   workplace_city  vacancies
# 0     ej angiven       5629
# 1      Stockholm       1515
# 2       Göteborg        587
# 3          Malmö        414
# 4      Linköping        260
# 5          Luleå        185
# 6        Uppsala        159
# 7          Gävle        140
# 8       Västerås        139
# 9     Norrköping         90

# %%
df_mart.groupby('employer_name')["vacancies"].sum().sort_values(ascending=False).reset_index()
# Out:
#                            employer_name  vacancies
# 0                       Vs Consulting AB       5200
# 1                             eLinked AB        320
# 2             Fordonsakademin Sverige AB        277
# 3     Studentconsulting Sweden AB (Publ)        224
# 4                       Aura Personal AB        194
# ...                                  ...        ...
# 1238                      Österlen VA AB          1
# 1239                    Öresundskraft AB          1
# 1240          Öregrund Marine Service AB          1
# 1241                  Örebro Universitet          1
# 1242                Örebro Bilservice AB          1
#
# [1243 rows x 2 columns]

# %%
occupation_fields = df_mart.groupby("occupation_field")["vacancies"].sum().sort_values(ascending=False).reset_index().head(5)
top_occupation = df_mart.groupby("occupation_field")["vacancies"].sum().sort_values(ascending=False).reset_index().head(5)

occ_1 = occupation_fields["vacancies"]
top_occupation
# Out:
#                  occupation_field  vacancies
# 0           Kultur, media, design       6172
# 1  Installation, drift, underhåll       5316
# 2        Kropps- och skönhetsvård        655

# %%
df_mart
# Out:
#                                                headline  \
# 0                                     Industrieketriker
# 1         Lagertekniker (Deltid/Extra) – Crona Software
# 2                                          Bilmekaniker
# 3                                     Verkstadstekniker
# 4                             Tågmontör med elkompetens
# ...                                                 ...
# 5116  ﻿A Less Ordinary Summer Job – Massageterapeut ...
# 5117                 Bibliotekarie till Påvelundsskolan
# 5118  ﻿A Less Ordinary Summer Job – Massageterapeut ...
# 5119                 Bibliotekarie till Påvelundsskolan
# 5120                 Bibliotekarie till Påvelundsskolan
#
#                    occupation  \
# 0          Industrielektriker
# 1       Servicetekniker, data
# 2         Personbilsmekaniker
# 3     Servicetekniker, maskin
# 4        Servicetekniker, tåg
# ...                       ...
# 5116   Massör/Massageterapeut
# 5117        Skolbibliotekarie
# 5118   Massör/Massageterapeut
# 5119        Skolbibliotekarie
# 5120        Skolbibliotekarie
#
#                                        occupation_group  \
# 0                                    Industrielektriker
# 1     Elektronikreparatörer och kommunikationselektr...
# 2          Motorfordonsmekaniker och fordonsreparatörer
# 3          Motorfordonsmekaniker och fordonsreparatörer
# 4             Underhållsmekaniker och maskinreparatörer
# ...                                                 ...
# 5116                     Massörer och massageterapeuter
# 5117                      Bibliotekarier och arkivarier
# 5118                     Massörer och massageterapeuter
# 5119                      Bibliotekarier och arkivarier
# 5120                      Bibliotekarier och arkivarier
#
#                     occupation_field  \
# 0     Installation, drift, underhåll
# 1     Installation, drift, underhåll
# 2     Installation, drift, underhåll
# 3     Installation, drift, underhåll
# 4     Installation, drift, underhåll
# ...                              ...
# 5116        Kropps- och skönhetsvård
# 5117           Kultur, media, design
# 5118        Kropps- och skönhetsvård
# 5119           Kultur, media, design
# 5120           Kultur, media, design
#
#                                             description  \
# 0     Tedelektro håller på att expandera och vi behö...
# 1     Lagertekniker (Deltid/Extra) – Crona Software\...
# 2     Vi söker en bilmekaniker som vill jobba anting...
# 3     Är du vår nya verkstadstekniker? Vi expander o...
# 4     Plats: Falköping\nStartdatum: 2025-05-15 \nAns...
# ...                                                 ...
# 5116  A Less Ordinary Summer Job – Massageterapeut p...
# 5117  I grundskoleförvaltningen har vi en trygg och ...
# 5118  A Less Ordinary Summer Job – Massageterapeut p...
# 5119  I grundskoleförvaltningen har vi en trygg och ...
# 5120  I grundskoleförvaltningen har vi en trygg och ...
#
#                            duration working_hours_type  scope_of_work_min  \
# 0                      Tills vidare             Heltid                100
# 1                        ej angiven               None               <NA>
# 2                      Tills vidare             Heltid                100
# 3                      Tills vidare             Heltid                100
# 4            6 månader eller längre             Heltid                100
# ...                             ...                ...                ...
# 5116  11 dagar - upp till 3 månader             Deltid                  0
# 5117                   Tills vidare             Heltid                100
# 5118  11 dagar - upp till 3 månader             Deltid                  0
# 5119                   Tills vidare             Heltid                100
# 5120                   Tills vidare             Heltid                100
#
#       scope_of_work_max  vacancies                            employer_name  \
# 0                   100          1                            Tedelektro AB
# 1                  <NA>          1                        Crona Software AB
# 2                   100          1  Landvetter Bilverkstad Br. Josefsson AB
# 3                   100          2                      Liebherr-Sverige AB
# 4                   100          1                      Railforce Sweden AB
# ...                 ...        ...                                      ...
# 5116                100          1                 Väderkullen The Lodge AB
# 5117                100          1                         GÖTEBORGS KOMMUN
# 5118                100          1                 Väderkullen The Lodge AB
# 5119                100          1                         GÖTEBORGS KOMMUN
# 5120                100          1                         GÖTEBORGS KOMMUN
#
#           workplace_region workplace_city  experience_required  \
# 0               ej angiven     ej angiven                 True
# 1                Skåne län    Helsingborg                 True
# 2     Västra götalands län        Härryda                 True
# 3         Västmanlands län       Västerås                 True
# 4     Västra götalands län      Falköping                 True
# ...                    ...            ...                  ...
# 5116             Skåne län           Lund                 True
# 5117  Västra götalands län       Göteborg                False
# 5118             Skåne län           Lund                 True
# 5119  Västra götalands län       Göteborg                False
# 5120  Västra götalands län       Göteborg                False
#
#       driving_license  access_to_own_car must_have_languages
# 0                True              False             Svenska
# 1                True              False             Svenska
# 2                True              False             Svenska
# 3                True              False   Engelska, Svenska
# 4                True              False   Engelska, Svenska
# ...               ...                ...                 ...
# 5116            False              False      ej specifierat
# 5117            False              False      ej specifierat
# 5118            False              False      ej specifierat
# 5119            False              False      ej specifierat
# 5120            False              False      ej specifierat
#
# [5121 rows x 17 columns]
